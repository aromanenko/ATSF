# %% [markdown]
# HSE, Applied Time Series Forecasitng , Winter 2022-23
#
# <font color="blue"> Lesson #7: Time Series Forecasting with ML </font>
#
# <span style="color:black; font-size: 12pt"></span>
#
# Alexey Romanenko,
# <font color="blue">alexromsput@gmail.com</font>

# %% [markdown]
# **Key words:**
#     - demand forecasting, lagged features, time series CV
#
# **Your feedback:**  please provide you feedback  <a href="https://forms.gle/bEV5iwmTqdM9rUoy8"> here </a>

# %% [markdown]
# # Demand Time Series

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from datetime import timedelta
from scipy import stats
from statsmodels.tsa import stattools
from copy import deepcopy

# don't forget to upload utils file to the colab session
from utils import qualityWAPE, qualityRMSE
import warnings, pylab

warnings.filterwarnings('ignore')

# setting of the plotting style, registers pandas date converters for matplotlib and the default figure size
import seaborn as sns
sns.set_style("darkgrid")
pd.plotting.register_matplotlib_converters()
# Default figure size
sns.mpl.rc("figure", figsize=(25, 5))
sns.mpl.rc("font", size=14)

# %%
# ! pip install --upgrade Cython
# ! pip install --upgrade git+https://github.com/statsmodels/statsmodels
import statsmodels.api as sm

# %%
# загружаем данные
ts_retail = pd.read_csv('https://raw.githubusercontent.com/aromanenko/ATSF/main/data/retail_2products.csv', sep=';')
ts_retail['Date'] = pd.to_datetime(ts_retail['Date'], dayfirst = True)
ts_retail.set_index(['Date'], inplace=True)
ts_retail.head()
# Out:
#             Store_id  SKU_id  Promo  Demand  Regular_Price  Promo_Price
# Date
# 2015-01-01         1       1    NaN    22.0         163.78          NaN
# 2015-01-02         1       1    NaN    41.0         163.78          NaN
# 2015-01-03         1       1    NaN    35.0         163.78          NaN
# 2015-01-04         1       1    NaN    72.0         163.78          NaN
# 2015-01-05         1       1    NaN    25.0         163.78          NaN

# %%
ts_retail['Demand'].plot()

# %%
# Fill missings  (note: step is domain specific)
ts_retail['Promo'] = ts_retail['Promo'].fillna(0)
ts_retail.reset_index().set_index(['SKU_id', 'Store_id', 'Date'], inplace=True)
ts_retail['Regular_Price'] = ts_retail['Regular_Price'].ffill().bfill()
ts_retail.reset_index().set_index(['Date'], inplace=True)
ts_retail[['Regular_Price']].plot()

# Add actual price (promo price when promo occurred or regular price otherwise)
plt.figure()
ts_retail['Actual_Price'] = ts_retail.Promo_Price.combine_first(ts_retail.Regular_Price) 
ts_retail[['Actual_Price']].plot()

# %%
# prepare test/train datasets
test_start_dt = '05-01-2016'
train = ts_retail.copy(deep=True)
train.loc[test_start_dt:, 'Demand'] = np.NaN
train.loc['01-01-2016':].plot()
test_y = ts_retail.loc[test_start_dt:, ['Store_id', 'SKU_id', 'Demand']]

plt.figure()
test_y.plot()

# %%
test_y.shape
# Out:
# (10502, 3)

# %%
# Aggregate on Sku - All Stores level
sales_by_sku = train.groupby(['SKU_id','Date']).agg({'Demand':'sum','Promo':'sum','Store_id':'count','Actual_Price':'mean'}).reset_index().set_index('Date')
sales_by_sku.loc[test_start_dt:,'Demand'] = np.NaN # fill test period Demand with Nan

sales_by_sku[sales_by_sku['SKU_id'] == 1][['Demand', 'Actual_Price']].plot(secondary_y = ['Actual_Price'])

sales_by_sku[sales_by_sku['SKU_id'] == 2][['Demand', 'Actual_Price']].plot(secondary_y = ['Actual_Price'])

sales_by_sku[sales_by_sku['SKU_id'] == 2][['Demand', 'Store_id']].plot(secondary_y = ['Store_id'])

# %% [markdown]
# # ML for time series Forecasting

# %% [markdown]
# **Questions**
# * Can classic ML algorithms (including DT regressor, Boosting, RF regressors)   be applied to the ts forecasting problem?
#   - Yes, assuming that ts model is defined properly
#
# * How CV should be organized for ts problem?
#
# <img src = 'https://miro.medium.com/max/753/1*qvdnPF8ETV9mFdMT0Y_BBA.png' width = '2500px'>

# %% [markdown]
# ## Feature generation for ML algorithms
# **Questions**
# * What features should be added to the original data set?
#    - Calendar-dummy variables: holidays, day of week, day of month
#    - Lagged-features
#    - x-sindicated features (e.g price x store_number**2)

# %%
# feature generation
data = sales_by_sku.reset_index().copy(deep = True)

data["weekday"] = data.Date.dt.weekday
data["monthday"] = data.Date.dt.day
data['is_weekend'] = data.weekday.isin([5,6])*1
data.head()
# Out:
#         Date  SKU_id  Demand  Promo  Store_id  Actual_Price  weekday  \
# 0 2015-01-01       1  1180.0    0.0        73    163.920685        3
# 1 2015-01-02       1  3667.0    0.0        73    163.920685        4
# 2 2015-01-03       1  4987.0    0.0        73    163.920685        5
# 3 2015-01-04       1  5226.0    0.0        73    163.920685        6
# 4 2015-01-05       1  5951.0    0.0        73    163.920685        0
#
#    monthday  is_weekend
# 0         1           0
# 1         2           0
# 2         3           1
# 3         4           1
# 4         5           0

# %% [markdown]
# ### Lagged Features Generation

# %% [markdown]
# **Questions**
# * Classic TS models leverage ts structure information (level, seasonaliry, trend, etc) for forecasting. How to provide such information for classsic ML models?
#
#   - Answer: use ES forecast as features for ML  -->
#      - Use more complicated ts based feature generation https://machinelearningmastery.com/basic-feature-engineering-time-series-data-python/
# <img src = 'https://github.com/aromanenko/ATSF/blob/main/pic/LaggedFeaturesGeneration.PNG?raw=true'>

# %%
from itertools import product
def percentile(n):
    '''Calculate n - percentile of data'''
    def percentile_(x):
        return np.percentile(x, n)
    percentile_.__name__ = 'pctl%s' % n
    return percentile_

# train[['SKU_id', 'Store_id', 'Demand']].groupby(['SKU_id', 'Store_id']).agg({'mean', 'std', percentile(50)})

# добавляем лаги
def lagged_features(df
                    , target_var = 'demand'
                    , org_id_columns = ['product_rk', 'store_location_rk']
                    , all_id_columns =['product_rk', 'store_location_rk', 'period_start_dt']
                    , lags = [7, 14, 21, 28]
                    , windows = [7, 14]
                    , aggregation_methods = {'mean', 'median', percentile(10),  percentile(90)}
                    , filters = None
                    ):
    '''Calculate lagged features '''
    ''' df - data frame
        target_var - column name which is used to calculate lagged features
        org_id_columns - id columns, lagged featires is calculated within each id element independatnly
        all_id_columns - id columns + timestamp column
        lags - 
        windows - list of windows, calculation is performed within time range length of window
        aggregation_methods - method of aggregation, e.g. 'mean', 'median', 'std', etc.
        filter = dict of dict: {<column_name>:{'postfix':'condition of the filter'}}
    '''
    out_df = deepcopy(df)

    if filters is None:
      filters = {'':{''}}

    keys, values = zip(*filters.items())
    for bundle in product(*values):
      # print(bundle)
        # define dates for each SKU and Store pairs        
      condition = ' & '.join([keys[i]+ filters[keys[i]][bundle[i]] for i in range(len(keys))])
      name =  '_'.join([bundle[i] for i in range(len(keys))])
      if len(condition) >0:
        _idx = df.eval(condition)
      else:
        _idx = df.index>=0
        
      if len(df[_idx].index)>0:
        for w in windows:
          lf_df = df[_idx].set_index(all_id_columns)[target_var].\
                    groupby(level=org_id_columns).apply(lambda x: x.rolling(window=w, min_periods = 1).agg(aggregation_methods))
          for l in lags:
            new_names = {x: "lag{0}_wdw{1}_{2}_{3}".
                          format(l, w, x, name) for x in lf_df.columns }

            out_df = pd.merge(out_df, lf_df.shift(l).reset_index().rename(columns = new_names),
                  how='left', on =all_id_columns )
            
    return out_df

# %% [markdown]
# **Questions**
#   * How to define lagges based on forecast horizon?
#     - Lag must be less or equal than forecast horizon in order to prevent target leakage!
#     - We are building forecast fot the next 22 days => minimal lag value is 22

# %%
flts = {'Promo': {'oprm':'>0', 'npromo':'==0', 'aprm':'>-1'}, 'weekday' : {'md':'==0', 'tue':'==1', 'wd':'==2', 'th':'==3', 'fr':'==4', 'sa':'==5', 'su':'==6', 'anyday':'>-1'}}
# data with added lagged features
data_lagged_features = lagged_features(data, target_var = 'Demand'
                    , org_id_columns = ['Store_id', 'SKU_id']
                    , all_id_columns =['Store_id', 'SKU_id', 'Date']
                    , lags = [22, 28]
                    , windows = [14, 28, 56]
                    , aggregation_methods = {'mean', 'median', percentile(10),  percentile(90)}
                    , filters = flts
                    )

# %%
# number of columns
print(len(data_lagged_features.columns))
data_lagged_features.columns
# Out:
# 585
# Index(['Date', 'SKU_id', 'Demand', 'Promo', 'Store_id', 'Actual_Price',
#        'weekday', 'monthday', 'is_weekend', 'lag22_wdw14_pctl10_oprm_md',
#        ...
#        'lag28_wdw28_pctl90_aprm_anyday', 'lag28_wdw28_median_aprm_anyday',
#        'lag22_wdw56_pctl10_aprm_anyday', 'lag22_wdw56_mean_aprm_anyday',
#        'lag22_wdw56_pctl90_aprm_anyday', 'lag22_wdw56_median_aprm_anyday',
#        'lag28_wdw56_pctl10_aprm_anyday', 'lag28_wdw56_mean_aprm_anyday',
#        'lag28_wdw56_pctl90_aprm_anyday', 'lag28_wdw56_median_aprm_anyday'],
#       dtype='object', length=585)

# %% [markdown]
# ## ML model definition
# **Questions**
# * Shall we train only one model for all data?
#
# <img src = 'https://github.com/aromanenko/ATSF/blob/main/pic/Informativity.png?raw=true'>
#
#  See details here
# http://www.machinelearning.ru/wiki/images/3/3e/Voron-ML-Logic.pdf
#
# * Can we define ML pipeline based on business logics?

# %%
# put date in index
data_lagged_features.set_index('Date', inplace = True)
data_lagged_features.loc[test_start_dt:].head()
# Out:
#             SKU_id  Demand  Promo  Store_id  Actual_Price  weekday  monthday  \
# Date
# 2016-05-01       1     NaN    0.0       103        131.16        6         1
# 2016-05-02       1     NaN    0.0       103        131.16        0         2
# 2016-05-03       1     NaN    0.0       103        131.16        1         3
# 2016-05-04       1     NaN    0.0       103        131.16        2         4
# 2016-05-05       1     NaN    0.0       103        131.16        3         5
#
#             is_weekend  lag22_wdw14_pctl10_oprm_md  lag22_wdw14_mean_oprm_md  \
# Date
# 2016-05-01           1                         NaN                       NaN
# 2016-05-02           0                         NaN                       NaN
# 2016-05-03           0                         NaN                       NaN
# 2016-05-04           0                         NaN                       NaN
# 2016-05-05           0                         NaN                       NaN
#
#             ...  lag28_wdw28_pctl90_aprm_anyday  \
# Date        ...
# 2016-05-01  ...                         14272.5
# 2016-05-02  ...                         14268.0
# 2016-05-03  ...                         14780.1
# 2016-05-04  ...                         14888.0
# 2016-05-05  ...                         14760.0
#
#             lag28_wdw28_median_aprm_anyday  lag22_wdw56_pctl10_aprm_anyday  \
# Date
# 2016-05-01                         13917.5                         13149.8
# 2016-05-02                         14239.0                         13198.6
# 2016-05-03                         14242.5                         13247.4
# 2016-05-04                         14246.0                         13296.2
# 2016-05-05                         14242.5                         13345.0
#
#             lag22_wdw56_mean_aprm_anyday  lag22_wdw56_pctl90_aprm_anyday  \
# Date
# 2016-05-01                  14495.083333                         16061.4
# 2016-05-02                  14442.769231                         16044.8
# 2016-05-03                  14435.571429                         16028.2
# 2016-05-04                  14426.266667                         16011.6
# 2016-05-05                  14376.812500                         15995.0
#
#             lag22_wdw56_median_aprm_anyday  lag28_wdw56_pctl10_aprm_anyday  \
# Date
# 2016-05-01                         14248.0                         13021.0
# 2016-05-02                         14246.0                         13037.0
# 2016-05-03                         14248.0                         13053.0
# 2016-05-04                         14250.0                         13069.0
# 2016-05-05                         14248.0                         13085.0
#
#             lag28_wdw56_mean_aprm_anyday  lag28_wdw56_pctl90_aprm_anyday  \
# Date
# 2016-05-01                  13737.000000                         14272.5
# 2016-05-02                  13808.714286                         14268.0
# 2016-05-03                  14071.625000                         14780.1
# 2016-05-04                  14133.888889                         14888.0
# 2016-05-05                  14126.900000                         14760.0
#
#             lag28_wdw56_median_aprm_anyday
# Date
# 2016-05-01                         13917.5
# 2016-05-02                         14239.0
# 2016-05-03                         14242.5
# 2016-05-04                         14246.0
# 2016-05-05                         14242.5
#
# [5 rows x 584 columns]

# %%
# train specific model for each SKU
sku1_train = data_lagged_features[data_lagged_features['SKU_id'] == 1]
sku2_train = data_lagged_features[data_lagged_features['SKU_id'] == 2]

# %% [markdown]
# ## ML Model Training

# %%
# try lightgbm as ml algorithm
import lightgbm as lgb
kwargs={'early_stopping_rounds':10,'verbose':2}

def plot_feature_importance(model, X , num = 20, fig_size = (40, 20)):
    feature_imp = pd.DataFrame({'Value':model.feature_importances_,'Feature':X.columns})
    plt.figure(figsize=fig_size)
    sns.set(font_scale = 5)
    sns.barplot(x="Value", y="Feature", data=feature_imp.sort_values(by="Value",
                                                        ascending=False)[0:num])
    plt.title('LightGBM Features (avg over folds)')
    plt.tight_layout()
    # plt.savefig('lgbm_importances-01.png')
    plt.show()

# %%
# without CV
lgbm1 = lgb.LGBMRegressor(
                        n_estimators=500,
                        learning_rate=0.1,
                        feature_fraction=0.7,
                        subsample=0.4,
                        num_leaves=40,
                        metric='mae')
lgbm1.fit(X = sku1_train.loc[:test_start_dt].drop(['SKU_id','Demand'], axis=1), y = sku1_train.loc[:test_start_dt].Demand)

lgbm2 = lgb.LGBMRegressor(
                        n_estimators=500,
                        learning_rate=0.1,
                        feature_fraction=0.7,
                        subsample=0.4,
                        num_leaves=40,
                        metric='mae')

lgbm2.fit(X = sku2_train.loc[:test_start_dt].drop(['SKU_id','Demand'], axis=1), y = sku2_train.loc[:test_start_dt].Demand)
# Out:
# LGBMRegressor(feature_fraction=0.7, metric='mae', n_estimators=500,
#               num_leaves=40, subsample=0.4)

# %%
plot_feature_importance(lgbm1, sku1_train[sku1_train.columns[2:]], num = 20)

# %%
plot_feature_importance(lgbm2, sku2_train[sku2_train.columns[2:]], num = 20)

# %% [markdown]
# ### Cross-validation for time series
#  **Caution**: ml parameters tuning steps are omitted! Only tech approach is shown.

# %%
#  time series cross validation
def performTimeSeriesCV(X_train, y_train, number_folds, model, metrics, kwargs={}):
    print('Size train set: {}'.format(X_train.shape))

    # size of a fold
    fold_size = int(np.floor(float(X_train.shape[0]) / number_folds))
    print('Size of each fold: {}'.format(fold_size))

    errors = np.zeros(number_folds-1)

    # loop from the first 2 folds to the total number of folds    
    for i in range(2, number_folds + 1):
        print('')
        train_share = float(i-1)/i
        print('Splitting the first ' + str(i) + ' chunks at ' + str(i-1) + '/' + str(i) )

        X = X_train[:(fold_size*i)]
        y = y_train[:(fold_size*i)]
        print('Size of train and test: {}'.format(X.shape)) # the size of the dataframe is going to be k*i

        index = int(np.floor(X.shape[0] * train_share))

        # folds used to train the model        
        X_trainFolds = X[:index]        
        y_trainFolds = y[:index]

        # fold used to test the model
        X_testFold = X[(index + 1):]
        y_testFold = y[(index + 1):]

        model.fit(X_trainFolds, y_trainFolds, **kwargs, eval_set=[(X_testFold, y_testFold)])
        errors[i-2] = metrics(model.predict(X_testFold), y_testFold)

    # the function returns the mean of the errors on the n-1 folds    
    return errors.mean()

# %%
# Train sets
X_train1 = sku1_train.loc[:test_start_dt].drop(['SKU_id','Demand'], axis=1)
y_train1 = sku1_train.loc[:test_start_dt].Demand
X_train2 = sku2_train.loc[:test_start_dt].drop(['SKU_id', 'Demand'], axis=1)
y_train2 = sku2_train.loc[:test_start_dt].Demand

# %%
# test sets
X_test1 = sku1_train.loc[test_start_dt:].drop(['SKU_id','Demand'], axis=1)
X_test2 = sku2_train.loc[test_start_dt:].drop(['SKU_id','Demand'], axis=1)

# %%
# WAPE realizaion for lgbm train
def wape(y_pred, y_true):
    res = np.sum(np.abs(y_true - y_pred)) / np.sum(y_true) * 100
    return res

# %%
# train for the sku 1
# %%time
performTimeSeriesCV(X_train1, y_train1, 17, lgbm1, wape, kwargs)
# Out:
# Size train set: (487, 582)
# Size of each fold: 28
#
# Splitting the first 2 chunks at 1/2
# Size of train + test: (56, 582)
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's l1: 10998.9
# [4]	valid_0's l1: 10998.9
# [6]	valid_0's l1: 10998.9
# [8]	valid_0's l1: 10998.9
# [10]	valid_0's l1: 10998.9
# Early stopping, best iteration is:
# [1]	valid_0's l1: 10998.9
#
# Splitting the first 3 chunks at 2/3
# Size of train + test: (84, 582)
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's l1: 23269.7
# [4]	valid_0's l1: 22533.2
# [6]	valid_0's l1: 22132.9
# [8]	valid_0's l1: 21893.4
# [10]	valid_0's l1: 21676.6
# [12]	valid_0's l1: 21471.6
# [14]	valid_0's l1: 21288.2
# [16]	valid_0's l1: 20887.8
# [18]	valid_0's l1: 20515.9
# [20]	valid_0's l1: 20161.8
# [22]	valid_0's l1: 20015.9
# [24]	valid_0's l1: 19685.9
# [26]	valid_0's l1: 19423.3
# [28]	valid_0's l1: 19469
# [30]	valid_0's l1: 19222.4
# [32]	valid_0's l1: 19043.7
# [34]	valid_0's l1: 18825.5
# [36]	valid_0's l1: 18685.6
# [38]	valid_0's l1: 18725
# [40]	valid_0's l1: 18518.3
# [42]	valid_0's l1: 18372.1
# [44]	valid_0's l1: 18230.8
# [46]	valid_0's l1: 18095.6
# [48]	valid_0's l1: 18039.4
# [50]	valid_0's l1: 18009
# [52]	valid_0's l1: 17931.1
# [54]	valid_0's l1: 17970.4
# [56]	valid_0's l1: 18013.6
# [58]	valid_0's l1: 18002.3
# [60]	valid_0's l1: 17858.9
# [62]	valid_0's l1: 17931.6
# Early stopping, best iteration is:
# [53]	valid_0's l1: 17856.2
#
# Splitting the first 4 chunks at 3/4
# Size of train + test: (112, 582)
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's l1: 18974.1
# [4]	valid_0's l1: 18559
# [6]	valid_0's l1: 18031.4
# [8]	valid_0's l1: 16364.5
# [10]	valid_0's l1: 14907.8
# [12]	valid_0's l1: 14148.2
# [14]	valid_0's l1: 14189.3
# [16]	valid_0's l1: 13981.8
# [18]	valid_0's l1: 14031.5
# [20]	valid_0's l1: 14365.4
# [22]	valid_0's l1: 14405.5
# [24]	valid_0's l1: 14218.9
# Early stopping, best iteration is:
# [15]	valid_0's l1: 13808.5
#
# Splitting the first 5 chunks at 4/5
# Size of train + test: (140, 582)
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's l1: 12253.1
# [4]	valid_0's l1: 13399.3
# [6]	valid_0's l1: 13824.5
# [8]	valid_0's l1: 11855
# [10]	valid_0's l1: 10217.8
# [12]	valid_0's l1: 10964.8
# [14]	valid_0's l1: 13255.4
# [16]	valid_0's l1: 13728.6
# [18]	valid_0's l1: 14176.8
# [20]	valid_0's l1: 14529.5
# Early stopping, best iteration is:
# [11]	valid_0's l1: 9521.19
#
# Splitting the first 6 chunks at 5/6
# Size of train + test: (168, 582)
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's l1: 14168.7
# [4]	valid_0's l1: 12228.5
# [6]	valid_0's l1: 9390.86
# [8]	valid_0's l1: 8823.45
# [10]	valid_0's l1: 8641.79
# [12]	valid_0's l1: 9269.96
# [14]	valid_0's l1: 9915.12
# [16]	valid_0's l1: 10474.6
# [18]	valid_0's l1: 11692.5
# [20]	valid_0's l1: 12394.7
# Early stopping, best iteration is:
# [11]	valid_0's l1: 8438.92
#
# Splitting the first 7 chunks at 6/7
# Size of train + test: (196, 582)
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's l1: 11839
# [4]	valid_0's l1: 9267.02
# [6]	valid_0's l1: 8310.18
# [8]	valid_0's l1: 7741.56
# [10]	valid_0's l1: 7025.9
# [12]	valid_0's l1: 6475.36
# [14]	valid_0's l1: 6607.14
# [16]	valid_0's l1: 6366.75
# [18]	valid_0's l1: 6135.7
# [20]	valid_0's l1: 6165.89
# [22]	valid_0's l1: 6290.55
# [24]	valid_0's l1: 6167.83
# [26]	valid_0's l1: 6657.67
# [28]	valid_0's l1: 6532.3
# Early stopping, best iteration is:
# [18]	valid_0's l1: 6135.7
#
# Splitting the first 8 chunks at 7/8
# Size of train + test: (224, 582)
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's l1: 21294.1
# [4]	valid_0's l1: 19804.7
# [6]	valid_0's l1: 18101
# [8]	valid_0's l1: 16873.7
# [10]	valid_0's l1: 16545.8
# [12]	valid_0's l1: 16455.1
# [14]	valid_0's l1: 15978
# [16]	valid_0's l1: 15520.9
# [18]	valid_0's l1: 15035.5
# [20]	valid_0's l1: 15057.1
# [22]	valid_0's l1: 14851
# [24]	valid_0's l1: 14895.9
# [26]	valid_0's l1: 14623.4
# [28]	valid_0's l1: 14162.2
# [30]	valid_0's l1: 14025.5
# [32]	valid_0's l1: 13656.9
# [34]	valid_0's l1: 13507.8
# [36]	valid_0's l1: 13789.9
# [38]	valid_0's l1: 13634.2
# [40]	valid_0's l1: 13826.9
# [42]	valid_0's l1: 13636.4
# Early stopping, best iteration is:
# [33]	valid_0's l1: 13255.2
#
# Splitting the first 9 chunks at 8/9
# Size of train + test: (252, 582)
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's l1: 4603.61
# [4]	valid_0's l1: 4549.97
# [6]	valid_0's l1: 4575.02
# [8]	valid_0's l1: 5400.31
# [10]	valid_0's l1: 5101.04
# [12]	valid_0's l1: 5011.46
# [14]	valid_0's l1: 4879.66
# Early stopping, best iteration is:
# [4]	valid_0's l1: 4549.97
#
# Splitting the first 10 chunks at 9/10
# Size of train + test: (280, 582)
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's l1: 8976.01
# [4]	valid_0's l1: 8879.55
# [6]	valid_0's l1: 9845.84
# [8]	valid_0's l1: 9791.1
# [10]	valid_0's l1: 10134.3
# Early stopping, best iteration is:
# [1]	valid_0's l1: 8807.58
#
# Splitting the first 11 chunks at 10/11
# Size of train + test: (308, 582)
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's l1: 11978
# [4]	valid_0's l1: 11391.5
# [6]	valid_0's l1: 12269.4
# [8]	valid_0's l1: 12139.7
# [10]	valid_0's l1: 11951.3
# [12]	valid_0's l1: 11899.6
# [14]	valid_0's l1: 11719.8
# Early stopping, best iteration is:
# [4]	valid_0's l1: 11391.5
#
# Splitting the first 12 chunks at 11/12
# Size of train + test: (336, 582)
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's l1: 30408
# [4]	valid_0's l1: 28894.5
# [6]	valid_0's l1: 26629.4
# [8]	valid_0's l1: 25108.5
# [10]	valid_0's l1: 24523.9
# [12]	valid_0's l1: 23495.3
# [14]	valid_0's l1: 22455.2
# [16]	valid_0's l1: 21610.2
# [18]	valid_0's l1: 20896.9
# [20]	valid_0's l1: 20353.3
# [22]	valid_0's l1: 19678.5
# [24]	valid_0's l1: 19083.1
# [26]	valid_0's l1: 18929.8
# [28]	valid_0's l1: 18597
# [30]	valid_0's l1: 18222.1
# [32]	valid_0's l1: 18059.9
# [34]	valid_0's l1: 17853.7
# [36]	valid_0's l1: 17667.7
# [38]	valid_0's l1: 17402.5
# [40]	valid_0's l1: 17459
# [42]	valid_0's l1: 17339.7
# [44]	valid_0's l1: 17167.4
# [46]	valid_0's l1: 16961.2
# [48]	valid_0's l1: 16940.3
# [50]	valid_0's l1: 16901
# [52]	valid_0's l1: 16858
# [54]	valid_0's l1: 16846
# [56]	valid_0's l1: 16740.7
# [58]	valid_0's l1: 16704.3
# [60]	valid_0's l1: 16769.2
# [62]	valid_0's l1: 16628.2
# [64]	valid_0's l1: 16622.7
# [66]	valid_0's l1: 16558.4
# [68]	valid_0's l1: 16581.9
# [70]	valid_0's l1: 16488.6
# [72]	valid_0's l1: 16474.3
# [74]	valid_0's l1: 16463.2
# [76]	valid_0's l1: 16406.3
# [78]	valid_0's l1: 16430.8
# [80]	valid_0's l1: 16446
# [82]	valid_0's l1: 16433
# [84]	valid_0's l1: 16418.2
# [86]	valid_0's l1: 16404.7
# [88]	valid_0's l1: 16342.9
# [90]	valid_0's l1: 16344.2
# [92]	valid_0's l1: 16302.6
# [94]	valid_0's l1: 16304.7
# [96]	valid_0's l1: 16297.8
# [98]	valid_0's l1: 16274.9
# [100]	valid_0's l1: 16222.5
# [102]	valid_0's l1: 16252.8
# [104]	valid_0's l1: 16297.8
# [106]	valid_0's l1: 16319.2
# [108]	valid_0's l1: 16313.8
# [110]	valid_0's l1: 16289.2
# Early stopping, best iteration is:
# [100]	valid_0's l1: 16222.5
#
# Splitting the first 13 chunks at 12/13
# Size of train + test: (364, 582)
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's l1: 15815.7
# [4]	valid_0's l1: 16539.8
# [6]	valid_0's l1: 15336.2
# [8]	valid_0's l1: 15084.6
# [10]	valid_0's l1: 14016.6
# [12]	valid_0's l1: 14348.5
# [14]	valid_0's l1: 13885.8
# [16]	valid_0's l1: 13153.6
# [18]	valid_0's l1: 12726.3
# [20]	valid_0's l1: 12194.9
# [22]	valid_0's l1: 12864
# [24]	valid_0's l1: 13361.9
# [26]	valid_0's l1: 13218.3
# [28]	valid_0's l1: 13724.5
# [30]	valid_0's l1: 14174.7
# Early stopping, best iteration is:
# [20]	valid_0's l1: 12194.9
#
# Splitting the first 14 chunks at 13/14
# Size of train + test: (392, 582)
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's l1: 7127.75
# [4]	valid_0's l1: 7193.44
# [6]	valid_0's l1: 7196.81
# [8]	valid_0's l1: 7146.5
# [10]	valid_0's l1: 7126.58
# [12]	valid_0's l1: 6499.29
# [14]	valid_0's l1: 6412.4
# [16]	valid_0's l1: 6336.55
# [18]	valid_0's l1: 6359.87
# [20]	valid_0's l1: 6424.21
# [22]	valid_0's l1: 6319.05
# [24]	valid_0's l1: 6324.51
# [26]	valid_0's l1: 6265.54
# [28]	valid_0's l1: 6320.2
# [30]	valid_0's l1: 6311.46
# [32]	valid_0's l1: 6305.05
# [34]	valid_0's l1: 5971.15
# [36]	valid_0's l1: 6006.34
# [38]	valid_0's l1: 6019.76
# [40]	valid_0's l1: 5933.53
# [42]	valid_0's l1: 6119.34
# [44]	valid_0's l1: 6175.08
# [46]	valid_0's l1: 6195.26
# [48]	valid_0's l1: 6305.15
# [50]	valid_0's l1: 5990.03
# Early stopping, best iteration is:
# [40]	valid_0's l1: 5933.53
#
# Splitting the first 15 chunks at 14/15
# Size of train + test: (420, 582)
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's l1: 11040.5
# [4]	valid_0's l1: 10110
# [6]	valid_0's l1: 9504.67
# [8]	valid_0's l1: 8933.88
# [10]	valid_0's l1: 7882.29
# [12]	valid_0's l1: 7011.86
# [14]	valid_0's l1: 6460.2
# [16]	valid_0's l1: 5971.17
# [18]	valid_0's l1: 5784.92
# [20]	valid_0's l1: 5715.94
# [22]	valid_0's l1: 5205.31
# [24]	valid_0's l1: 5230.48
# [26]	valid_0's l1: 4979.9
# [28]	valid_0's l1: 4892.03
# [30]	valid_0's l1: 4821.24
# [32]	valid_0's l1: 4888.35
# [34]	valid_0's l1: 4813.54
# [36]	valid_0's l1: 4685.94
# [38]	valid_0's l1: 4792.31
# [40]	valid_0's l1: 4792.58
# [42]	valid_0's l1: 4908.87
# [44]	valid_0's l1: 4870.29
# [46]	valid_0's l1: 4819.26
# Early stopping, best iteration is:
# [36]	valid_0's l1: 4685.94
#
# Splitting the first 16 chunks at 15/16
# Size of train + test: (448, 582)
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's l1: 13504.3
# [4]	valid_0's l1: 11079.3
# [6]	valid_0's l1: 9717.4
# [8]	valid_0's l1: 8791.16
# [10]	valid_0's l1: 8063.19
# [12]	valid_0's l1: 7803.08
# [14]	valid_0's l1: 7458.33
# [16]	valid_0's l1: 7045.79
# [18]	valid_0's l1: 6806.07
# [20]	valid_0's l1: 6979.43
# [22]	valid_0's l1: 6986.26
# [24]	valid_0's l1: 6777.3
# [26]	valid_0's l1: 6919.76
# [28]	valid_0's l1: 7101.59
# [30]	valid_0's l1: 7018.98
# [32]	valid_0's l1: 6961.89
# [34]	valid_0's l1: 6953.06
# Early stopping, best iteration is:
# [24]	valid_0's l1: 6777.3
#
# Splitting the first 17 chunks at 16/17
# Size of train + test: (476, 582)
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's l1: 19272
# [4]	valid_0's l1: 16915.7
# [6]	valid_0's l1: 14952.6
# [8]	valid_0's l1: 13388.9
# [10]	valid_0's l1: 11968.1
# [12]	valid_0's l1: 11095.4
# [14]	valid_0's l1: 10250.9
# [16]	valid_0's l1: 9733.23
# [18]	valid_0's l1: 9117.86
# [20]	valid_0's l1: 8651.96
# [22]	valid_0's l1: 8330.72
# [24]	valid_0's l1: 8081.62
# [26]	valid_0's l1: 7762.78
# [28]	valid_0's l1: 7786
# [30]	valid_0's l1: 7697.45
# [32]	valid_0's l1: 7775.3
# [34]	valid_0's l1: 7799.07
# [36]	valid_0's l1: 7707.66
# [38]	valid_0's l1: 7799.9
# [40]	valid_0's l1: 7757.19
# Early stopping, best iteration is:
# [31]	valid_0's l1: 7643.16
# CPU times: user 6.31 s, sys: 67.1 ms, total: 6.38 s
# Wall time: 5.98 s
# 32.773171871188396

# %% [markdown]
# ## Forecast Generation with ML

# %%
# forecast for sku 1
X_test1['y_pred'] = lgbm1.predict(X_test1)
X_test1['y_pred'].plot()

# %%
# train for product 2
performTimeSeriesCV(X_train2, y_train2, 17, lgbm2, wape, kwargs)
# Out:
# Size train set: (487, 582)
# Size of each fold: 28
#
# Splitting the first 2 chunks at 1/2
# Size of train + test: (56, 582)
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's l1: 222.772
# [4]	valid_0's l1: 222.772
# [6]	valid_0's l1: 222.772
# [8]	valid_0's l1: 222.772
# [10]	valid_0's l1: 222.772
# Early stopping, best iteration is:
# [1]	valid_0's l1: 222.772
#
# Splitting the first 3 chunks at 2/3
# Size of train + test: (84, 582)
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's l1: 89.289
# [4]	valid_0's l1: 89.5793
# [6]	valid_0's l1: 87.219
# [8]	valid_0's l1: 85.2159
# [10]	valid_0's l1: 82.9107
# [12]	valid_0's l1: 81.2074
# [14]	valid_0's l1: 79.4275
# [16]	valid_0's l1: 76.0255
# [18]	valid_0's l1: 74.4589
# [20]	valid_0's l1: 71.6875
# [22]	valid_0's l1: 70.5314
# [24]	valid_0's l1: 69.2897
# [26]	valid_0's l1: 68.1957
# [28]	valid_0's l1: 66.0936
# [30]	valid_0's l1: 65.1191
# [32]	valid_0's l1: 64.2443
# [34]	valid_0's l1: 62.5834
# [36]	valid_0's l1: 60.9842
# [38]	valid_0's l1: 60.022
# [40]	valid_0's l1: 58.5299
# [42]	valid_0's l1: 57.1671
# [44]	valid_0's l1: 55.7207
# [46]	valid_0's l1: 55.0452
# [48]	valid_0's l1: 53.6599
# [50]	valid_0's l1: 52.422
# [52]	valid_0's l1: 51.1163
# [54]	valid_0's l1: 50.7139
# [56]	valid_0's l1: 49.3069
# [58]	valid_0's l1: 48.6126
# [60]	valid_0's l1: 47.6849
# [62]	valid_0's l1: 46.806
# [64]	valid_0's l1: 46.6544
# [66]	valid_0's l1: 45.6844
# [68]	valid_0's l1: 45.1324
# [70]	valid_0's l1: 44.3474
# [72]	valid_0's l1: 43.5226
# [74]	valid_0's l1: 43.0771
# [76]	valid_0's l1: 42.3161
# [78]	valid_0's l1: 42.2479
# [80]	valid_0's l1: 41.4791
# [82]	valid_0's l1: 40.7953
# [84]	valid_0's l1: 40.3974
# [86]	valid_0's l1: 39.9891
# [88]	valid_0's l1: 39.3318
# [90]	valid_0's l1: 39.1178
# [92]	valid_0's l1: 38.5545
# [94]	valid_0's l1: 37.8574
# [96]	valid_0's l1: 37.6451
# [98]	valid_0's l1: 37.2971
# [100]	valid_0's l1: 36.9281
# [102]	valid_0's l1: 36.73
# [104]	valid_0's l1: 35.9523
# [106]	valid_0's l1: 35.7479
# [108]	valid_0's l1: 35.1147
# [110]	valid_0's l1: 34.7657
# [112]	valid_0's l1: 34.633
# [114]	valid_0's l1: 34.4756
# [116]	valid_0's l1: 34.205
# [118]	valid_0's l1: 33.9629
# [120]	valid_0's l1: 33.7433
# [122]	valid_0's l1: 33.2205
# [124]	valid_0's l1: 33.258
# [126]	valid_0's l1: 32.9839
# [128]	valid_0's l1: 32.4741
# [130]	valid_0's l1: 32.4747
# [132]	valid_0's l1: 31.9498
# [134]	valid_0's l1: 31.9893
# [136]	valid_0's l1: 31.8692
# [138]	valid_0's l1: 31.2896
# [140]	valid_0's l1: 31.0334
# [142]	valid_0's l1: 31.4621
# [144]	valid_0's l1: 31.2178
# [146]	valid_0's l1: 30.9971
# [148]	valid_0's l1: 30.7699
# [150]	valid_0's l1: 30.5254
# [152]	valid_0's l1: 30.4767
# [154]	valid_0's l1: 30.5129
# [156]	valid_0's l1: 30.0495
# [158]	valid_0's l1: 30.087
# [160]	valid_0's l1: 30.5021
# [162]	valid_0's l1: 30.4614
# [164]	valid_0's l1: 30.3857
# [166]	valid_0's l1: 30.1634
# Early stopping, best iteration is:
# [156]	valid_0's l1: 30.0495
#
# Splitting the first 4 chunks at 3/4
# Size of train + test: (112, 582)
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's l1: 69.2382
# [4]	valid_0's l1: 59.8623
# [6]	valid_0's l1: 52.7345
# [8]	valid_0's l1: 46.4356
# [10]	valid_0's l1: 41.4747
# [12]	valid_0's l1: 38.0221
# [14]	valid_0's l1: 36.5135
# [16]	valid_0's l1: 34.4318
# [18]	valid_0's l1: 32.1342
# [20]	valid_0's l1: 31.008
# [22]	valid_0's l1: 29.337
# [24]	valid_0's l1: 28.7523
# [26]	valid_0's l1: 28.0175
# [28]	valid_0's l1: 27.7006
# [30]	valid_0's l1: 27.5925
# [32]	valid_0's l1: 27.4818
# [34]	valid_0's l1: 26.7916
# [36]	valid_0's l1: 27.0193
# [38]	valid_0's l1: 26.8512
# [40]	valid_0's l1: 26.758
# [42]	valid_0's l1: 26.4741
# [44]	valid_0's l1: 26.5347
# [46]	valid_0's l1: 26.0683
# [48]	valid_0's l1: 26.2105
# [50]	valid_0's l1: 26.0023
# [52]	valid_0's l1: 26.1034
# [54]	valid_0's l1: 26.1367
# [56]	valid_0's l1: 25.9502
# [58]	valid_0's l1: 25.8536
# [60]	valid_0's l1: 26.0551
# [62]	valid_0's l1: 26.158
# [64]	valid_0's l1: 26.1135
# [66]	valid_0's l1: 26.3098
# Early stopping, best iteration is:
# [57]	valid_0's l1: 25.8411
#
# Splitting the first 5 chunks at 4/5
# Size of train + test: (140, 582)
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's l1: 64.6729
# [4]	valid_0's l1: 57.2706
# [6]	valid_0's l1: 52.2077
# [8]	valid_0's l1: 47.6879
# [10]	valid_0's l1: 44.0044
# [12]	valid_0's l1: 41.6138
# [14]	valid_0's l1: 41.3261
# [16]	valid_0's l1: 40.2077
# [18]	valid_0's l1: 39.3926
# [20]	valid_0's l1: 38.9685
# [22]	valid_0's l1: 38.6906
# [24]	valid_0's l1: 38.3898
# [26]	valid_0's l1: 37.9169
# [28]	valid_0's l1: 37.669
# [30]	valid_0's l1: 37.2704
# [32]	valid_0's l1: 37.0465
# [34]	valid_0's l1: 37.4534
# [36]	valid_0's l1: 37.4561
# [38]	valid_0's l1: 37.4404
# [40]	valid_0's l1: 37.5769
# [42]	valid_0's l1: 37.6833
# Early stopping, best iteration is:
# [32]	valid_0's l1: 37.0465
#
# Splitting the first 6 chunks at 5/6
# Size of train + test: (168, 582)
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's l1: 46.3764
# [4]	valid_0's l1: 40.2398
# [6]	valid_0's l1: 35.1156
# [8]	valid_0's l1: 31.9607
# [10]	valid_0's l1: 28.7833
# [12]	valid_0's l1: 27.012
# [14]	valid_0's l1: 26.157
# [16]	valid_0's l1: 26.0191
# [18]	valid_0's l1: 25.6469
# [20]	valid_0's l1: 25.555
# [22]	valid_0's l1: 25.0929
# [24]	valid_0's l1: 24.2655
# [26]	valid_0's l1: 23.7583
# [28]	valid_0's l1: 23.6932
# [30]	valid_0's l1: 23.8193
# [32]	valid_0's l1: 24.1185
# [34]	valid_0's l1: 24.362
# [36]	valid_0's l1: 24.9372
# Early stopping, best iteration is:
# [27]	valid_0's l1: 23.4576
#
# Splitting the first 7 chunks at 6/7
# Size of train + test: (196, 582)
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's l1: 37.5721
# [4]	valid_0's l1: 38.8148
# [6]	valid_0's l1: 39.4736
# [8]	valid_0's l1: 40.9329
# [10]	valid_0's l1: 42.7683
# Early stopping, best iteration is:
# [1]	valid_0's l1: 36.8311
#
# Splitting the first 8 chunks at 7/8
# Size of train + test: (224, 582)
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's l1: 341.596
# [4]	valid_0's l1: 344.165
# [6]	valid_0's l1: 346.091
# [8]	valid_0's l1: 347.624
# [10]	valid_0's l1: 349.917
# Early stopping, best iteration is:
# [1]	valid_0's l1: 339.306
#
# Splitting the first 9 chunks at 8/9
# Size of train + test: (252, 582)
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's l1: 2710.65
# [4]	valid_0's l1: 2678.21
# [6]	valid_0's l1: 2653.27
# [8]	valid_0's l1: 2631.42
# [10]	valid_0's l1: 2628.07
# [12]	valid_0's l1: 2602.5
# [14]	valid_0's l1: 2590.35
# [16]	valid_0's l1: 2581.15
# [18]	valid_0's l1: 2568.74
# [20]	valid_0's l1: 2558.34
# [22]	valid_0's l1: 2549.78
# [24]	valid_0's l1: 2545.28
# [26]	valid_0's l1: 2544.77
# [28]	valid_0's l1: 2543.33
# [30]	valid_0's l1: 2541.77
# [32]	valid_0's l1: 2538.24
# [34]	valid_0's l1: 2535.68
# [36]	valid_0's l1: 2534.52
# [38]	valid_0's l1: 2533.38
# [40]	valid_0's l1: 2532.29
# [42]	valid_0's l1: 2531.33
# [44]	valid_0's l1: 2531.16
# [46]	valid_0's l1: 2529.76
# [48]	valid_0's l1: 2529.54
# [50]	valid_0's l1: 2528.48
# [52]	valid_0's l1: 2527.26
# [54]	valid_0's l1: 2525.83
# [56]	valid_0's l1: 2525.85
# [58]	valid_0's l1: 2524.67
# [60]	valid_0's l1: 2523.56
# [62]	valid_0's l1: 2523.14
# [64]	valid_0's l1: 2522.35
# [66]	valid_0's l1: 2521.92
# [68]	valid_0's l1: 2520.19
# [70]	valid_0's l1: 2521.49
# [72]	valid_0's l1: 2520.78
# [74]	valid_0's l1: 2519.93
# [76]	valid_0's l1: 2520.1
# [78]	valid_0's l1: 2519.6
# [80]	valid_0's l1: 2518.88
# [82]	valid_0's l1: 2517.51
# [84]	valid_0's l1: 2518.14
# [86]	valid_0's l1: 2518.18
# [88]	valid_0's l1: 2518.53
# [90]	valid_0's l1: 2518.21
# [92]	valid_0's l1: 2518.11
# Early stopping, best iteration is:
# [82]	valid_0's l1: 2517.51
#
# Splitting the first 10 chunks at 9/10
# Size of train + test: (280, 582)
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's l1: 785.913
# [4]	valid_0's l1: 923.63
# [6]	valid_0's l1: 1025.63
# [8]	valid_0's l1: 1114.64
# [10]	valid_0's l1: 1180.33
# Early stopping, best iteration is:
# [1]	valid_0's l1: 601.235
#
# Splitting the first 11 chunks at 10/11
# Size of train + test: (308, 582)
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's l1: 1234.3
# [4]	valid_0's l1: 1135.94
# [6]	valid_0's l1: 1069.79
# [8]	valid_0's l1: 971.355
# [10]	valid_0's l1: 897.929
# [12]	valid_0's l1: 836.212
# [14]	valid_0's l1: 777.005
# [16]	valid_0's l1: 708.419
# [18]	valid_0's l1: 634.666
# [20]	valid_0's l1: 524.906
# [22]	valid_0's l1: 487.824
# [24]	valid_0's l1: 481.031
# [26]	valid_0's l1: 454.735
# [28]	valid_0's l1: 426.716
# [30]	valid_0's l1: 319.88
# [32]	valid_0's l1: 339.685
# [34]	valid_0's l1: 310.722
# [36]	valid_0's l1: 268.334
# [38]	valid_0's l1: 250.605
# [40]	valid_0's l1: 338.949
# [42]	valid_0's l1: 328.542
# [44]	valid_0's l1: 355.249
# [46]	valid_0's l1: 406.116
# [48]	valid_0's l1: 436.939
# Early stopping, best iteration is:
# [38]	valid_0's l1: 250.605
#
# Splitting the first 12 chunks at 11/12
# Size of train + test: (336, 582)
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's l1: 418.822
# [4]	valid_0's l1: 396.712
# [6]	valid_0's l1: 342.749
# [8]	valid_0's l1: 312.378
# [10]	valid_0's l1: 283.062
# [12]	valid_0's l1: 255.847
# [14]	valid_0's l1: 249.732
# [16]	valid_0's l1: 241.03
# [18]	valid_0's l1: 240.999
# [20]	valid_0's l1: 234.333
# [22]	valid_0's l1: 224.232
# [24]	valid_0's l1: 213.28
# [26]	valid_0's l1: 207.835
# [28]	valid_0's l1: 197.335
# [30]	valid_0's l1: 199.138
# [32]	valid_0's l1: 190.679
# [34]	valid_0's l1: 192.192
# [36]	valid_0's l1: 182.524
# [38]	valid_0's l1: 182.996
# [40]	valid_0's l1: 183.985
# [42]	valid_0's l1: 174.105
# [44]	valid_0's l1: 194.188
# [46]	valid_0's l1: 198.56
# [48]	valid_0's l1: 201.257
# [50]	valid_0's l1: 198.785
# [52]	valid_0's l1: 188.605
# Early stopping, best iteration is:
# [43]	valid_0's l1: 169.564
#
# Splitting the first 13 chunks at 12/13
# Size of train + test: (364, 582)
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's l1: 2006.59
# [4]	valid_0's l1: 1803.14
# [6]	valid_0's l1: 1587.75
# [8]	valid_0's l1: 1411.21
# [10]	valid_0's l1: 1275
# [12]	valid_0's l1: 1170
# [14]	valid_0's l1: 1091.26
# [16]	valid_0's l1: 1021.04
# [18]	valid_0's l1: 978.073
# [20]	valid_0's l1: 927.811
# [22]	valid_0's l1: 888.539
# [24]	valid_0's l1: 857.135
# [26]	valid_0's l1: 826.695
# [28]	valid_0's l1: 797.553
# [30]	valid_0's l1: 774.291
# [32]	valid_0's l1: 741.204
# [34]	valid_0's l1: 721.356
# [36]	valid_0's l1: 701.99
# [38]	valid_0's l1: 692.254
# [40]	valid_0's l1: 668.074
# [42]	valid_0's l1: 646.976
# [44]	valid_0's l1: 628.797
# [46]	valid_0's l1: 613.512
# [48]	valid_0's l1: 599.948
# [50]	valid_0's l1: 586.658
# [52]	valid_0's l1: 582.959
# [54]	valid_0's l1: 563.212
# [56]	valid_0's l1: 555.021
# [58]	valid_0's l1: 539.047
# [60]	valid_0's l1: 528.554
# [62]	valid_0's l1: 526.976
# [64]	valid_0's l1: 517.166
# [66]	valid_0's l1: 507.681
# [68]	valid_0's l1: 500.031
# [70]	valid_0's l1: 494.396
# [72]	valid_0's l1: 485.334
# [74]	valid_0's l1: 483.927
# [76]	valid_0's l1: 482.149
# [78]	valid_0's l1: 481.955
# [80]	valid_0's l1: 481.357
# [82]	valid_0's l1: 475.39
# [84]	valid_0's l1: 470.061
# [86]	valid_0's l1: 469.699
# [88]	valid_0's l1: 469.132
# [90]	valid_0's l1: 469.016
# [92]	valid_0's l1: 467.49
# [94]	valid_0's l1: 468.327
# [96]	valid_0's l1: 466.106
# [98]	valid_0's l1: 462.314
# [100]	valid_0's l1: 462.568
# [102]	valid_0's l1: 460.865
# [104]	valid_0's l1: 458.342
# [106]	valid_0's l1: 457.514
# [108]	valid_0's l1: 460.132
# [110]	valid_0's l1: 457.964
# [112]	valid_0's l1: 457.819
# [114]	valid_0's l1: 456.325
# [116]	valid_0's l1: 455.211
# [118]	valid_0's l1: 453.178
# [120]	valid_0's l1: 452.311
# [122]	valid_0's l1: 451.808
# [124]	valid_0's l1: 450.625
# [126]	valid_0's l1: 448.56
# [128]	valid_0's l1: 446.086
# [130]	valid_0's l1: 445.371
# [132]	valid_0's l1: 448.543
# [134]	valid_0's l1: 446.147
# [136]	valid_0's l1: 445.973
# [138]	valid_0's l1: 444.283
# [140]	valid_0's l1: 443.221
# [142]	valid_0's l1: 441.48
# [144]	valid_0's l1: 438.967
# [146]	valid_0's l1: 441.488
# [148]	valid_0's l1: 441.435
# [150]	valid_0's l1: 438.664
# [152]	valid_0's l1: 439.133
# [154]	valid_0's l1: 437.937
# [156]	valid_0's l1: 436.951
# [158]	valid_0's l1: 435.67
# [160]	valid_0's l1: 434.48
# [162]	valid_0's l1: 433.754
# [164]	valid_0's l1: 432.644
# [166]	valid_0's l1: 433.282
# [168]	valid_0's l1: 432.948
# [170]	valid_0's l1: 431.165
# [172]	valid_0's l1: 430.8
# [174]	valid_0's l1: 430.974
# [176]	valid_0's l1: 429.5
# [178]	valid_0's l1: 430.201
# [180]	valid_0's l1: 429.463
# [182]	valid_0's l1: 428.303
# [184]	valid_0's l1: 427.813
# [186]	valid_0's l1: 427.475
# [188]	valid_0's l1: 425.719
# [190]	valid_0's l1: 425.583
# [192]	valid_0's l1: 424.804
# [194]	valid_0's l1: 423.929
# [196]	valid_0's l1: 423.695
# [198]	valid_0's l1: 422.075
# [200]	valid_0's l1: 423.35
# [202]	valid_0's l1: 423.204
# [204]	valid_0's l1: 422.021
# [206]	valid_0's l1: 420.909
# [208]	valid_0's l1: 421.258
# [210]	valid_0's l1: 420.314
# [212]	valid_0's l1: 420.609
# [214]	valid_0's l1: 419.859
# [216]	valid_0's l1: 419.097
# [218]	valid_0's l1: 419.466
# [220]	valid_0's l1: 418.436
# [222]	valid_0's l1: 417.158
# [224]	valid_0's l1: 417.702
# [226]	valid_0's l1: 417.022
# [228]	valid_0's l1: 416.25
# [230]	valid_0's l1: 415.74
# [232]	valid_0's l1: 416.198
# [234]	valid_0's l1: 414.807
# [236]	valid_0's l1: 414.318
# [238]	valid_0's l1: 414.898
# [240]	valid_0's l1: 413.497
# [242]	valid_0's l1: 412.577
# [244]	valid_0's l1: 412.225
# [246]	valid_0's l1: 412.469
# [248]	valid_0's l1: 411.849
# [250]	valid_0's l1: 412.355
# [252]	valid_0's l1: 411.918
# [254]	valid_0's l1: 411.469
# [256]	valid_0's l1: 410.498
# [258]	valid_0's l1: 410.787
# [260]	valid_0's l1: 411.102
# [262]	valid_0's l1: 410.617
# [264]	valid_0's l1: 409.966
# [266]	valid_0's l1: 409.231
# [268]	valid_0's l1: 408.936
# [270]	valid_0's l1: 409.033
# [272]	valid_0's l1: 408.661
# [274]	valid_0's l1: 408.43
# [276]	valid_0's l1: 407.676
# [278]	valid_0's l1: 407.843
# [280]	valid_0's l1: 407.179
# [282]	valid_0's l1: 407.248
# [284]	valid_0's l1: 407.287
# [286]	valid_0's l1: 407.228
# [288]	valid_0's l1: 406.874
# [290]	valid_0's l1: 406.329
# [292]	valid_0's l1: 406.048
# [294]	valid_0's l1: 406.06
# [296]	valid_0's l1: 405.538
# [298]	valid_0's l1: 405.444
# [300]	valid_0's l1: 405.112
# [302]	valid_0's l1: 404.434
# [304]	valid_0's l1: 404.53
# [306]	valid_0's l1: 403.792
# [308]	valid_0's l1: 403.587
# [310]	valid_0's l1: 403.214
# [312]	valid_0's l1: 403.165
# [314]	valid_0's l1: 402.66
# [316]	valid_0's l1: 402.213
# [318]	valid_0's l1: 401.925
# [320]	valid_0's l1: 401.536
# [322]	valid_0's l1: 401.635
# [324]	valid_0's l1: 400.733
# [326]	valid_0's l1: 400.383
# [328]	valid_0's l1: 399.945
# [330]	valid_0's l1: 399.927
# [332]	valid_0's l1: 399.539
# [334]	valid_0's l1: 399.436
# [336]	valid_0's l1: 399.266
# [338]	valid_0's l1: 399.612
# [340]	valid_0's l1: 399.431
# [342]	valid_0's l1: 399.162
# [344]	valid_0's l1: 399.408
# [346]	valid_0's l1: 399.103
# [348]	valid_0's l1: 398.915
# [350]	valid_0's l1: 398.69
# [352]	valid_0's l1: 398.593
# [354]	valid_0's l1: 398.32
# [356]	valid_0's l1: 397.567
# [358]	valid_0's l1: 397.592
# [360]	valid_0's l1: 397.464
# [362]	valid_0's l1: 396.752
# [364]	valid_0's l1: 396.311
# [366]	valid_0's l1: 396.192
# [368]	valid_0's l1: 396.361
# [370]	valid_0's l1: 396.057
# [372]	valid_0's l1: 395.716
# [374]	valid_0's l1: 395.578
# [376]	valid_0's l1: 395.259
# [378]	valid_0's l1: 395.076
# [380]	valid_0's l1: 394.85
# [382]	valid_0's l1: 394.193
# [384]	valid_0's l1: 394.006
# [386]	valid_0's l1: 394.065
# [388]	valid_0's l1: 394.218
# [390]	valid_0's l1: 393.83
# [392]	valid_0's l1: 393.622
# [394]	valid_0's l1: 393.416
# [396]	valid_0's l1: 393.124
# [398]	valid_0's l1: 392.758
# [400]	valid_0's l1: 392.517
# [402]	valid_0's l1: 392.123
# [404]	valid_0's l1: 391.813
# [406]	valid_0's l1: 391.813
# [408]	valid_0's l1: 391.704
# [410]	valid_0's l1: 391.192
# [412]	valid_0's l1: 391.075
# [414]	valid_0's l1: 390.651
# [416]	valid_0's l1: 391.052
# [418]	valid_0's l1: 390.85
# [420]	valid_0's l1: 390.688
# [422]	valid_0's l1: 390.509
# [424]	valid_0's l1: 390.271
# [426]	valid_0's l1: 390.297
# [428]	valid_0's l1: 390.328
# [430]	valid_0's l1: 389.974
# [432]	valid_0's l1: 389.634
# [434]	valid_0's l1: 389.443
# [436]	valid_0's l1: 389.41
# [438]	valid_0's l1: 389.537
# [440]	valid_0's l1: 389.694
# [442]	valid_0's l1: 389.57
# [444]	valid_0's l1: 389.266
# [446]	valid_0's l1: 389.172
# [448]	valid_0's l1: 388.837
# [450]	valid_0's l1: 388.419
# [452]	valid_0's l1: 388.473
# [454]	valid_0's l1: 388.199
# [456]	valid_0's l1: 387.87
# [458]	valid_0's l1: 387.679
# [460]	valid_0's l1: 387.611
# [462]	valid_0's l1: 387.386
# [464]	valid_0's l1: 387.349
# [466]	valid_0's l1: 387.062
# [468]	valid_0's l1: 386.823
# [470]	valid_0's l1: 386.99
# [472]	valid_0's l1: 386.667
# [474]	valid_0's l1: 386.633
# [476]	valid_0's l1: 386.421
# [478]	valid_0's l1: 386.028
# [480]	valid_0's l1: 385.759
# [482]	valid_0's l1: 385.65
# [484]	valid_0's l1: 385.598
# [486]	valid_0's l1: 385.446
# [488]	valid_0's l1: 385.335
# [490]	valid_0's l1: 385.427
# [492]	valid_0's l1: 385.386
# [494]	valid_0's l1: 385.006
# [496]	valid_0's l1: 385.111
# [498]	valid_0's l1: 384.679
# [500]	valid_0's l1: 384.762
# Did not meet early stopping. Best iteration is:
# [499]	valid_0's l1: 384.592
#
# Splitting the first 14 chunks at 13/14
# Size of train + test: (392, 582)
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's l1: 2611.46
# [4]	valid_0's l1: 2322.17
# [6]	valid_0's l1: 2099.75
# [8]	valid_0's l1: 1924.64
# [10]	valid_0's l1: 1789.32
# [12]	valid_0's l1: 1668.05
# [14]	valid_0's l1: 1579.13
# [16]	valid_0's l1: 1496.66
# [18]	valid_0's l1: 1467.23
# [20]	valid_0's l1: 1419.15
# [22]	valid_0's l1: 1379.46
# [24]	valid_0's l1: 1373.48
# [26]	valid_0's l1: 1346.18
# [28]	valid_0's l1: 1324.94
# [30]	valid_0's l1: 1300.83
# [32]	valid_0's l1: 1283.52
# [34]	valid_0's l1: 1276.56
# [36]	valid_0's l1: 1258.84
# [38]	valid_0's l1: 1245.59
# [40]	valid_0's l1: 1225.46
# [42]	valid_0's l1: 1217.95
# [44]	valid_0's l1: 1209.96
# [46]	valid_0's l1: 1202.67
# [48]	valid_0's l1: 1183.6
# [50]	valid_0's l1: 1176.64
# [52]	valid_0's l1: 1171
# [54]	valid_0's l1: 1167.47
# [56]	valid_0's l1: 1158.12
# [58]	valid_0's l1: 1164.29
# [60]	valid_0's l1: 1157.16
# [62]	valid_0's l1: 1150.05
# [64]	valid_0's l1: 1142.66
# [66]	valid_0's l1: 1136.56
# [68]	valid_0's l1: 1136.12
# [70]	valid_0's l1: 1137.26
# [72]	valid_0's l1: 1142.83
# [74]	valid_0's l1: 1137.55
# [76]	valid_0's l1: 1132.15
# [78]	valid_0's l1: 1134.33
# [80]	valid_0's l1: 1127.89
# [82]	valid_0's l1: 1128.38
# [84]	valid_0's l1: 1117.3
# [86]	valid_0's l1: 1120.38
# [88]	valid_0's l1: 1120.9
# [90]	valid_0's l1: 1125.98
# [92]	valid_0's l1: 1128.31
# [94]	valid_0's l1: 1123.08
# Early stopping, best iteration is:
# [84]	valid_0's l1: 1117.3
#
# Splitting the first 15 chunks at 14/15
# Size of train + test: (420, 582)
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's l1: 2546.95
# [4]	valid_0's l1: 2246.87
# [6]	valid_0's l1: 2002.74
# [8]	valid_0's l1: 1795.09
# [10]	valid_0's l1: 1598.44
# [12]	valid_0's l1: 1461.34
# [14]	valid_0's l1: 1332.27
# [16]	valid_0's l1: 1228.63
# [18]	valid_0's l1: 1152.03
# [20]	valid_0's l1: 1071.79
# [22]	valid_0's l1: 1007.6
# [24]	valid_0's l1: 949.426
# [26]	valid_0's l1: 941.437
# [28]	valid_0's l1: 959.178
# [30]	valid_0's l1: 958.25
# [32]	valid_0's l1: 980.593
# [34]	valid_0's l1: 940.597
# [36]	valid_0's l1: 964.372
# [38]	valid_0's l1: 972.625
# [40]	valid_0's l1: 962.315
# [42]	valid_0's l1: 947.21
# [44]	valid_0's l1: 957.025
# Early stopping, best iteration is:
# [34]	valid_0's l1: 940.597
#
# Splitting the first 16 chunks at 15/16
# Size of train + test: (448, 582)
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's l1: 1205.32
# [4]	valid_0's l1: 796.398
# [6]	valid_0's l1: 655.025
# [8]	valid_0's l1: 574.916
# [10]	valid_0's l1: 544.213
# [12]	valid_0's l1: 432.729
# [14]	valid_0's l1: 348.027
# [16]	valid_0's l1: 298.995
# [18]	valid_0's l1: 352.018
# [20]	valid_0's l1: 389.803
# [22]	valid_0's l1: 434.58
# [24]	valid_0's l1: 474.61
# Early stopping, best iteration is:
# [15]	valid_0's l1: 296.147
#
# Splitting the first 17 chunks at 16/17
# Size of train + test: (476, 582)
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's l1: 964.617
# [4]	valid_0's l1: 793.901
# [6]	valid_0's l1: 660.405
# [8]	valid_0's l1: 589.639
# [10]	valid_0's l1: 526.233
# [12]	valid_0's l1: 464.344
# [14]	valid_0's l1: 418.052
# [16]	valid_0's l1: 376.924
# [18]	valid_0's l1: 316.815
# [20]	valid_0's l1: 287.308
# [22]	valid_0's l1: 253.458
# [24]	valid_0's l1: 236.294
# [26]	valid_0's l1: 222.886
# [28]	valid_0's l1: 201.388
# [30]	valid_0's l1: 183.281
# [32]	valid_0's l1: 172.856
# [34]	valid_0's l1: 159.122
# [36]	valid_0's l1: 149.498
# [38]	valid_0's l1: 141.588
# [40]	valid_0's l1: 130.562
# [42]	valid_0's l1: 131.212
# [44]	valid_0's l1: 134.896
# [46]	valid_0's l1: 132.54
# [48]	valid_0's l1: 135.832
# [50]	valid_0's l1: 148.165
# Early stopping, best iteration is:
# [40]	valid_0's l1: 130.562
# 37.7015865536558

# %%
# forecast for sku 2
# X_test2['y_pred'] = lgbm2.predict(X_test2)
X_test2['y_pred'].plot()
ax = X_test2['Promo'].plot(secondary_y = True)
ax.legend()

# %%
y_true = test_y.groupby(['SKU_id','Date']).agg({'Demand':'sum'}).reset_index().set_index('Date')

# WAPE for sku 1
qlt , _ = qualityWAPE(y_true[y_true['SKU_id']==1]['Demand'], X_test1['y_pred'])

#draw forecast and actuals
X_test1.merge(y_true[y_true['SKU_id']==1], how = 'inner', left_index = True, right_index = True)[['Demand', 'y_pred']].plot(title = 'WAPE='+str(qlt))

# %%
# WAPE for sku 2
qlt , _ = qualityWAPE(y_true[y_true['SKU_id']==2]['Demand'], X_test2['y_pred'])

#draw forecast and actuals
X_test2.merge(y_true[y_true['SKU_id']==2], how = 'inner', left_index = True, right_index = True)[['Demand', 'y_pred']].plot(title = 'WAPE='+str(qlt))

# %% [markdown]
# **Materials**
# * Cross-validation for time series https://medium.com/@soumyachess1496/cross-validation-in-time-series-566ae4981ce4
# * M - competition
#   - M5: https://www.kaggle.com/c/m5-forecasting-accuracy/discussion/163414
#   - M4: https://www.sciencedirect.com/science/article/pii/S0169207019301128
